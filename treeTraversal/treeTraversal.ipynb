# %%
import Tree
import numpy as np
import sys

# %load_ext autoreload
# %autoreload 2

sys.setrecursionlimit(512)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
preorder = [6,4,31,2,5]
inorder = list(preorder)
inorder.sort()
print('preorder = '+str(preorder))
print('inorder = '+str(inorder))
tree = Tree.deserializePreIn(preorder,inorder)

'''
treeSerial = Tree.serialize(tree)
print('treeSerial = '+str(treeSerial))

tree2 = Tree.deserialize(treeSerial)
'''
# Out:
# preorder = [6, 4, 31, 2, 5]
# inorder = [2, 4, 5, 6, 31]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-54063b85bd6f> in <module>()
#       4 print('preorder = '+str(preorder))
#       5 print('inorder = '+str(inorder))
# ----> 6 tree = Tree.deserializePreIn(preorder,inorder)
#       7
#       8 '''
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn(preorder, inorder)
#      49         return None
#      50
# ---> 51     return deserializePreIn_recur(0,0,N-1,preorder,inorder)
#      52
#      53 def deserializePreIn_recur(preStart,inStart,inEnd,preorder,inorder):
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      59     if inRoot-1 >= inStart:
#      60         # root of the left subtree is next in preorder
# ---> 61         root.left = deserializePreIn_recur(preStart+1,inStart,inRoot-1,preorder,inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      59     if inRoot-1 >= inStart:
#      60         # root of the left subtree is next in preorder
# ---> 61         root.left = deserializePreIn_recur(preStart+1,inStart,inRoot-1,preorder,inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ...
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      62     if inRoot+1 <= inEnd:
#      63         # root of the right subtree is next to preorder + # of nodes in the left subtree
# ---> 64         root.right = deserializePreIn_recur(preStart+inRoot-inStart+1,inRoot+1,inEnd,preorder,inorder)
#      65
#      66     return root
#
# /mnt/c/cygwin64/home/UyenBui/randProbs/treeTraversal/Tree.py in deserializePreIn_recur(preStart, inStart, inEnd, preorder, inorder)
#      55         return None
#      56
# ---> 57     root = TreeNode(preorder[preStart])
#      58     inRoot = inorder.index(preorder[preStart])
#      59     if inRoot-1 >= inStart:
#
# RuntimeError: maximum recursion depth exceeded
