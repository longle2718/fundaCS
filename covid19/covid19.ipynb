# %%
import matplotlib.pyplot as plt
import covid19

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
valfun, policy = covid19.optimize()

# %%
covid19.visualize(8, policy)

# %%
covid19.visualize(1, policy)
