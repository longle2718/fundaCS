# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import IQA

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# read images
imgBlur = cv2.imread('blur.jpg')
imgClear = cv2.imread('clear.jpg')

# %%
plt.figure(figsize=(10,5))
plt.imshow(imgBlur)
plt.figure(figsize=(10,5))
plt.imshow(imgClear)

# %%
# variance of laplacian for blur detection
gray = cv2.cvtColor(imgBlur, cv2.COLOR_BGR2GRAY)
stat = IQA.variance_of_laplacian(gray)
print('stat = %s' % stat)

gray = cv2.cvtColor(imgClear, cv2.COLOR_BGR2GRAY)
stat = IQA.variance_of_laplacian(gray)
print('stat = %s' % stat)
# Out:
# stat = 6.9153951911
# stat = 721.211271096
