# %%
import Trie
import SufTreeNode
import utils

# %load_ext autoreload
# %autoreload 2

# %%
words = ['box$', 'boxing$', 'baby$', 'base$', 'dance$', 'dad$', 'dady$']
mTrie = Trie.buildTrie(words)
#print(mTrie.val)

# %%
buf = utils.allWords(mTrie,plot=True)
print('buf = %s' % buf)
# Out:
# buf = ['baby$', 'base$', 'boxing$', 'box$', 'dady$', 'dad$', 'dance$']

# %%
buf = utils.autocomplete(mTrie,'dad')
print('buf = %s' % buf)
# Out:
# buf = ['dady$', 'dad$']

# %%
words = ['abaab'] # 'BANANA$' 'ababc$' 'abaab$'
mSufTree = SufTreeNode.buildSufTree(words)
# Out:
# suf = abaab
# suf = baab
# suf = aab
# suf = ab

# %%
buf = utils.allWords(mSufTree,plot=True)
print('buf = %s' % buf)
# Out:
# buf = ['baab', 'ab', 'abaab', 'aab']
