# %%
import Trie

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
words = ['box', 'baby', 'base', 'dance', 'dad']
mTrie = Trie.buildTrie(words)

# %%
buf = Trie.allWords(mTrie,plot=True)
print('buf = %s' % buf)
# Out:
# stack = ['b', 'o', 'x']
# [<Trie.TrieNode object at 0x7f067bcd9ef0>, <Trie.TrieNode object at 0x7f067be7b898>]
# stack = ['b', 'a', 'b', 'y']
# [<Trie.TrieNode object at 0x7f067bcd9ef0>, <Trie.TrieNode object at 0x7f067bcd9748>]
# stack = ['b', 'a', 's', 'e']
# ...
# stack = ['d', 'a', 'n', 'c', 'e']
# ...
# stack = ['d', 'a', 'd']
# []
# buf = ['box', 'baby', 'base', 'dance', 'dad']

# %%
print(mTrie)
# Out:
# None
