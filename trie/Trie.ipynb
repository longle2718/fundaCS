# %%
import Trie

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
words = ['baby', 'bad', 'bank', 'box', 'dad', 'dance']
mTrie = Trie.buildTrie(words)

# %%
buf = Trie.preTraverse(mTrie,plot=True)
print('buf = %s' % buf)
# Out:
# buf = ['b', 'a', 'b', 'y', 'd', 'n', 'k', 'o', 'x', 'd', 'a', 'd', 'n', 'c', 'e']

# %%
print(mTrie)
# Out:
# None
