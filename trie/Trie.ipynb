# %%
import Trie

# %load_ext autoreload
# %autoreload 2

# %%
words = ['box$', 'boxing$', 'baby$', 'base$', 'dance$', 'dad$', 'dady$', 'dada$']
mTrie = Trie.buildTrie(words)

# %%
buf = Trie.allWords(mTrie,plot=True)
print('buf = %s' % buf)
# Out:
# child.val,loc = d,(-0.5, -1.0)
# child.val,loc = b,(0.5, -1.0)
# child.val,loc = ba,(0.14644660940672616, -2.0)
# child.val,loc = bo,(0.98734302466044077, -2.0)
# child.val,loc = box,(0.73734302466044088, -3.0)
# child.val,loc = boxi,(0.56056632936380402, -4.0)
# child.val,loc = box$,(1.1551698868651645, -4.0)
# child.val,loc = boxin,(0.43556632936380402, -5.0)
# child.val,loc = boxing,(0.34717798171548553, -6.0)
# child.val,loc = boxing$,(0.28467798171548553, -7.0)
# child.val,loc = bas,(-0.10355339059327379, -3.0)
# child.val,loc = bab,(0.60355339059327373, -3.0)
# child.val,loc = baby,(0.42677669529663687, -4.0)
# child.val,loc = baby$,(0.30177669529663687, -5.0)
# child.val,loc = base,(-0.28033008588991065, -4.0)
# child.val,loc = base$,(-0.40533008588991065, -5.0)
# child.val,loc = da,(-0.85355339059327384, -2.0)
# child.val,loc = dad,(-1.1035533905932737, -3.0)
# child.val,loc = dan,(-0.39644660940672632, -3.0)
# child.val,loc = danc,(-0.57322330470336325, -4.0)
# ...

# %%
buf = Trie.autocomplete(mTrie,'bo')
print('buf = %s' % buf)
# Out:
# buf = bo
