# %%
import Trie

# %load_ext autoreload
# %autoreload 2

# %%
words = ['box$', 'boxing$', 'baby$', 'base$', 'dance$', 'dad$', 'dady$']
mTrie = Trie.buildTrie(words)
#print(mTrie.val)

# %%
buf = Trie.allWords(mTrie,plot=True)
print('buf = %s' % buf)
# Out:
# buf = ['box$', 'boxing$', 'baby$', 'base$', 'dance$', 'dady$', 'dad$']

# %%
buf = Trie.autocomplete(mTrie,'dad')
print('buf = %s' % buf)
# Out:
# buf = ['dady$', 'dad$']
